# %%
# !python --version
# Out:
# Python 3.10.14

# %%
# !pip install mediapipe
# Out:
# Collecting mediapipe
#   Downloading mediapipe-0.10.11-cp310-cp310-win_amd64.whl.metadata (9.8 kB)
# Collecting absl-py (from mediapipe)
#   Using cached absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting attrs>=19.1.0 (from mediapipe)
#   Using cached attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting flatbuffers>=2.0 (from mediapipe)
#   Using cached flatbuffers-24.3.25-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting jax (from mediapipe)
#   Downloading jax-0.4.26-py3-none-any.whl.metadata (23 kB)
# Collecting matplotlib (from mediapipe)
#   Downloading matplotlib-3.8.4-cp310-cp310-win_amd64.whl.metadata (5.9 kB)
# Collecting numpy (from mediapipe)
#   Downloading numpy-1.26.4-cp310-cp310-win_amd64.whl.metadata (61 kB)
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ---------------------------------------- 61.0/61.0 kB 3.4 MB/s eta 0:00:00
# Collecting opencv-contrib-python (from mediapipe)
#   Downloading opencv_contrib_python-4.9.0.80-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Collecting protobuf<4,>=3.11 (from mediapipe)
#   Downloading protobuf-3.20.3-cp310-cp310-win_amd64.whl.metadata (698 bytes)
# Collecting sounddevice>=0.4.4 (from mediapipe)
#   Downloading sounddevice-0.4.6-py3-none-win_amd64.whl.metadata (1.4 kB)
# Collecting CFFI>=1.0 (from sounddevice>=0.4.4->mediapipe)
#   Downloading cffi-1.16.0-cp310-cp310-win_amd64.whl.metadata (1.5 kB)
# Collecting ml-dtypes>=0.2.0 (from jax->mediapipe)
#   Downloading ml_dtypes-0.4.0-cp310-cp310-win_amd64.whl.metadata (20 kB)
# Collecting opt-einsum (from jax->mediapipe)
#   Using cached opt_einsum-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting scipy>=1.9 (from jax->mediapipe)
#   Downloading scipy-1.13.0-cp310-cp310-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.6 kB ? eta -:--:--
#      ---------------------------------------- 60.6/60.6 kB 3.1 MB/s eta 0:00:00
# Collecting contourpy>=1.0.1 (from matplotlib->mediapipe)
#   Downloading contourpy-1.2.1-cp310-cp310-win_amd64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib->mediapipe)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->mediapipe)
#   Downloading fonttools-4.51.0-cp310-cp310-win_amd64.whl.metadata (162 kB)
#      ---------------------------------------- 0.0/162.8 kB ? eta -:--:--
#      -------------------------------------- 162.8/162.8 kB 4.9 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib->mediapipe)
#   Using cached kiwisolver-1.4.5-cp310-cp310-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\ignac\local\test\.conda\lib\site-packages (from matplotlib->mediapipe) (24.0)
# Collecting pillow>=8 (from matplotlib->mediapipe)
#   Downloading pillow-10.3.0-cp310-cp310-win_amd64.whl.metadata (9.4 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib->mediapipe)
#   Downloading pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ignac\local\test\.conda\lib\site-packages (from matplotlib->mediapipe) (2.9.0)
# Collecting pycparser (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe)
#   Using cached pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Requirement already satisfied: six>=1.5 in c:\users\ignac\local\test\.conda\lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)
# Downloading mediapipe-0.10.11-cp310-cp310-win_amd64.whl (50.8 MB)
#    ---------------------------------------- 0.0/50.8 MB ? eta -:--:--
#    ---------------------------------------- 0.5/50.8 MB 9.6 MB/s eta 0:00:06
#     --------------------------------------- 1.1/50.8 MB 11.9 MB/s eta 0:00:05
#    - -------------------------------------- 1.9/50.8 MB 13.6 MB/s eta 0:00:04
#    -- ------------------------------------- 3.0/50.8 MB 15.8 MB/s eta 0:00:04
#    --- ------------------------------------ 4.2/50.8 MB 17.9 MB/s eta 0:00:03
#    ---- ----------------------------------- 5.7/50.8 MB 20.2 MB/s eta 0:00:03
#    ----- ---------------------------------- 7.3/50.8 MB 22.3 MB/s eta 0:00:02
#    ------- -------------------------------- 9.2/50.8 MB 24.5 MB/s eta 0:00:02
#    -------- ------------------------------- 11.3/50.8 MB 31.2 MB/s eta 0:00:02
#    ---------- ----------------------------- 13.7/50.8 MB 38.5 MB/s eta 0:00:01
#    ------------ --------------------------- 16.1/50.8 MB 43.5 MB/s eta 0:00:01
#    -------------- ------------------------- 17.8/50.8 MB 46.7 MB/s eta 0:00:01
#    -------------- ------------------------- 17.8/50.8 MB 46.7 MB/s eta 0:00:01
#    -------------- ------------------------- 17.8/50.8 MB 46.7 MB/s eta 0:00:01
#    -------------- ------------------------- 18.6/50.8 MB 29.7 MB/s eta 0:00:02
#    -------------- ------------------------- 19.0/50.8 MB 28.4 MB/s eta 0:00:02
#    --------------- ------------------------ 19.1/50.8 MB 26.2 MB/s eta 0:00:02
#    --------------- ------------------------ 19.1/50.8 MB 23.4 MB/s eta 0:00:02
#    --------------- ------------------------ 19.2/50.8 MB 19.8 MB/s eta 0:00:02
#    --------------- ------------------------ 19.4/50.8 MB 18.2 MB/s eta 0:00:02
#    --------------- ------------------------ 19.6/50.8 MB 16.8 MB/s eta 0:00:02
#    --------------- ------------------------ 20.2/50.8 MB 16.0 MB/s eta 0:00:02
#    ------------------ --------------------- 23.0/50.8 MB 16.4 MB/s eta 0:00:02
#    -------------------- ------------------- 25.9/50.8 MB 16.4 MB/s eta 0:00:02
#    ---------------------- ----------------- 28.5/50.8 MB 21.8 MB/s eta 0:00:02
#    ------------------------ --------------- 31.6/50.8 MB 59.5 MB/s eta 0:00:01
#    --------------------------- ------------ 34.3/50.8 MB 59.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 37.4/50.8 MB 59.8 MB/s eta 0:00:01
#    ------------------------------- -------- 40.3/50.8 MB 65.6 MB/s eta 0:00:01
#    --------------------------------- ------ 43.1/50.8 MB 65.2 MB/s eta 0:00:01
#    ------------------------------------ --- 46.3/50.8 MB 59.5 MB/s eta 0:00:01
#    -------------------------------------- - 49.4/50.8 MB 65.6 MB/s eta 0:00:01
#    ---------------------------------------  50.8/50.8 MB 65.2 MB/s eta 0:00:01
#    ---------------------------------------- 50.8/50.8 MB 46.7 MB/s eta 0:00:00
# Using cached attrs-23.2.0-py3-none-any.whl (60 kB)
# Using cached flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Downloading protobuf-3.20.3-cp310-cp310-win_amd64.whl (904 kB)
#    ---------------------------------------- 0.0/904.0 kB ? eta -:--:--
#    --------------------------------------- 904.0/904.0 kB 55.9 MB/s eta 0:00:00
# Downloading sounddevice-0.4.6-py3-none-win_amd64.whl (199 kB)
#    ---------------------------------------- 0.0/199.7 kB ? eta -:--:--
#    --------------------------------------- 199.7/199.7 kB 12.6 MB/s eta 0:00:00
# Using cached absl_py-2.1.0-py3-none-any.whl (133 kB)
# Downloading jax-0.4.26-py3-none-any.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ---------------------------------------- 1.9/1.9 MB 59.6 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp310-cp310-win_amd64.whl (15.8 MB)
#    ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#    ------ --------------------------------- 2.4/15.8 MB 51.6 MB/s eta 0:00:01
#    ------------- -------------------------- 5.4/15.8 MB 58.0 MB/s eta 0:00:01
#    --------------------- ------------------ 8.6/15.8 MB 61.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 11.5/15.8 MB 65.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 13.9/15.8 MB 65.6 MB/s eta 0:00:01
#    ---------------------------------------  15.8/15.8 MB 59.5 MB/s eta 0:00:01
#    ---------------------------------------- 15.8/15.8 MB 54.4 MB/s eta 0:00:00
# Downloading matplotlib-3.8.4-cp310-cp310-win_amd64.whl (7.7 MB)
#    ---------------------------------------- 0.0/7.7 MB ? eta -:--:--
#    -------------- ------------------------- 2.7/7.7 MB 59.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.6/7.7 MB 60.0 MB/s eta 0:00:01
#    ---------------------------------------- 7.7/7.7 MB 61.2 MB/s eta 0:00:00
# Downloading opencv_contrib_python-4.9.0.80-cp37-abi3-win_amd64.whl (45.3 MB)
#    ---------------------------------------- 0.0/45.3 MB ? eta -:--:--
#    -- ------------------------------------- 2.7/45.3 MB 56.4 MB/s eta 0:00:01
#    ---- ----------------------------------- 4.8/45.3 MB 61.8 MB/s eta 0:00:01
#    ------ --------------------------------- 7.8/45.3 MB 62.1 MB/s eta 0:00:01
#    --------- ------------------------------ 11.0/45.3 MB 59.5 MB/s eta 0:00:01
#    ------------ --------------------------- 13.9/45.3 MB 59.5 MB/s eta 0:00:01
#    -------------- ------------------------- 16.9/45.3 MB 59.8 MB/s eta 0:00:01
#    ----------------- ---------------------- 19.5/45.3 MB 59.5 MB/s eta 0:00:01
#    ------------------- -------------------- 22.4/45.3 MB 65.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 25.2/45.3 MB 65.6 MB/s eta 0:00:01
#    ------------------------- -------------- 28.4/45.3 MB 65.6 MB/s eta 0:00:01
#    --------------------------- ------------ 31.6/45.3 MB 65.6 MB/s eta 0:00:01
#    ------------------------------ --------- 34.4/45.3 MB 65.6 MB/s eta 0:00:01
#    --------------------------------- ------ 37.5/45.3 MB 65.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 40.2/45.3 MB 65.6 MB/s eta 0:00:01
#    -------------------------------------- - 43.0/45.3 MB 65.2 MB/s eta 0:00:01
#    ---------------------------------------  45.3/45.3 MB 65.6 MB/s eta 0:00:01
#    ---------------------------------------  45.3/45.3 MB 65.6 MB/s eta 0:00:01
#    ---------------------------------------  45.3/45.3 MB 65.6 MB/s eta 0:00:01
#    ---------------------------------------  45.3/45.3 MB 65.6 MB/s eta 0:00:01
#    ---------------------------------------- 45.3/45.3 MB 31.2 MB/s eta 0:00:00
# Downloading cffi-1.16.0-cp310-cp310-win_amd64.whl (181 kB)
#    ---------------------------------------- 0.0/181.6 kB ? eta -:--:--
#    --------------------------------------- 181.6/181.6 kB 10.7 MB/s eta 0:00:00
# Downloading contourpy-1.2.1-cp310-cp310-win_amd64.whl (187 kB)
#    ---------------------------------------- 0.0/187.5 kB ? eta -:--:--
#    ---------------------------------------- 187.5/187.5 kB ? eta 0:00:00
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.51.0-cp310-cp310-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 46.3 MB/s eta 0:00:00
# Using cached kiwisolver-1.4.5-cp310-cp310-win_amd64.whl (56 kB)
# Downloading ml_dtypes-0.4.0-cp310-cp310-win_amd64.whl (126 kB)
#    ---------------------------------------- 0.0/126.6 kB ? eta -:--:--
#    ---------------------------------------- 126.6/126.6 kB ? eta 0:00:00
# Downloading pillow-10.3.0-cp310-cp310-win_amd64.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 2.5/2.5 MB 81.3 MB/s eta 0:00:00
# Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#    ---------------------------------------- 0.0/103.2 kB ? eta -:--:--
#    ---------------------------------------- 103.2/103.2 kB ? eta 0:00:00
# Downloading scipy-1.13.0-cp310-cp310-win_amd64.whl (46.2 MB)
#    ---------------------------------------- 0.0/46.2 MB ? eta -:--:--
#    -- ------------------------------------- 3.4/46.2 MB 110.7 MB/s eta 0:00:01
#    ----- ---------------------------------- 6.3/46.2 MB 80.5 MB/s eta 0:00:01
#    -------- ------------------------------- 9.4/46.2 MB 75.0 MB/s eta 0:00:01
#    ---------- ----------------------------- 12.6/46.2 MB 65.2 MB/s eta 0:00:01
#    ------------- -------------------------- 15.7/46.2 MB 72.6 MB/s eta 0:00:01
#    --------------- ------------------------ 18.2/46.2 MB 65.6 MB/s eta 0:00:01
#    ------------------ --------------------- 21.3/46.2 MB 65.6 MB/s eta 0:00:01
#    --------------------- ------------------ 24.6/46.2 MB 65.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 27.5/46.2 MB 65.6 MB/s eta 0:00:01
#    -------------------------- ------------- 30.3/46.2 MB 65.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 33.4/46.2 MB 65.6 MB/s eta 0:00:01
#    ------------------------------- -------- 36.5/46.2 MB 65.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 39.5/46.2 MB 72.6 MB/s eta 0:00:01
#    ------------------------------------ --- 42.5/46.2 MB 65.6 MB/s eta 0:00:01
#    ---------------------------------------  45.5/46.2 MB 65.6 MB/s eta 0:00:01
#    ---------------------------------------  46.2/46.2 MB 65.6 MB/s eta 0:00:01
#    ---------------------------------------- 46.2/46.2 MB 50.4 MB/s eta 0:00:00
# Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Using cached pycparser-2.22-py3-none-any.whl (117 kB)
# Installing collected packages: flatbuffers, pyparsing, pycparser, protobuf, pillow, numpy, kiwisolver, fonttools, cycler, attrs, absl-py, scipy, opt-einsum, opencv-contrib-python, ml-dtypes, contourpy, CFFI, sounddevice, matplotlib, jax, mediapipe
# Successfully installed CFFI-1.16.0 absl-py-2.1.0 attrs-23.2.0 contourpy-1.2.1 cycler-0.12.1 flatbuffers-24.3.25 fonttools-4.51.0 jax-0.4.26 kiwisolver-1.4.5 matplotlib-3.8.4 mediapipe-0.10.11 ml-dtypes-0.4.0 numpy-1.26.4 opencv-contrib-python-4.9.0.80 opt-einsum-3.3.0 pillow-10.3.0 protobuf-3.20.3 pycparser-2.22 pyparsing-3.1.2 scipy-1.13.0 sounddevice-0.4.6

# %%
import cv2
import mediapipe as mp
import numpy as np
from google.colab.patches import cv2_imshow

mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

video_path = '11_28_22-player9.webm'
cap = cv2.VideoCapture(video_path)

## Setup mediapipe instance
with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor image to RGB
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
      
        # Make detection
        results = pose.process(image)
    
        # Recolor back to BGR
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # Render detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                                mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=2), 
                                mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2) 
                                 )               
        
        cv2_imshow(image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()
