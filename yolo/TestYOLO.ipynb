# %%
# !python --version
# Out:
# Python 3.10.9

# %%
# !pip install --ignore-installed ultralytics
# Out:
# ...
#      ---------------------------------------- 0.0/41.2 kB ? eta -:--:--
#      ------------------ ------------------- 20.5/41.2 kB 320.0 kB/s eta 0:00:01
#      -------------------------------------- 41.2/41.2 kB 491.6 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/60.6 kB ? eta -:--:--
#      ---------------------------------------- 60.6/60.6 kB ? eta 0:00:00
# ...
#      ---------------------------------------- 0.0/57.6 kB ? eta -:--:--
#      ---------------------------------------- 57.6/57.6 kB ? eta 0:00:00
# ...
#      ---------------------------------------- 0.0/165.5 kB ? eta -:--:--
#      ------------------------------------- 165.5/165.5 kB 10.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ---------------------------------------- 61.0/61.0 kB 3.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/780.5 kB ? eta -:--:--
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n-pose.pt')  # load an official model

# Predict with the model
# results = model('11_28_22-player9.webm',max_det=1, show=True, save=True)  # predict on a video file
# Run inference on an image with YOLOv8n

#!yolo predict model=yolov8n.pt source='videoframe_0.jpg' #clasifica a la persona y los puntos del suelo: yolo\runs\detect\predict\videoframe_0.jpg
# !yolo predict model=yolov8n-pose.pt source='videoframe_0.jpg' #pose estimation: yolo\runs\pose\predict\videoframe_0.jpg
# Out:
# Ultralytics YOLOv8.2.29 🚀 Python-3.11.5 torch-2.3.1+cpu CPU (Intel Core(TM) i5-10300H 2.50GHz)
# YOLOv8n-pose summary (fused): 187 layers, 3289964 parameters, 0 gradients, 9.2 GFLOPs
#
# image 1/1 c:\Users\franf\USM\Vision por Computador\pose_tracker\yolo\videoframe_0.jpg: 384x640 2 persons, 173.6ms
# Speed: 8.0ms preprocess, 173.6ms inference, 12.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\pose\predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
